# %% [markdown]
# # CPSC 368 Impact By Disease (KNM Neighbours)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from IPython.display import display

# %%
USCDI = pd.read_csv('final_datasets_V1/cleaned/USCDI.csv')
KFF2019_new = pd.read_csv("final_datasets_V1/cleaned/KFF2019_new.csv")

# %%
print("DataFrame shape:", USCDI.shape)
# Out:
# DataFrame shape: (8592, 13)

# %% [markdown]
# After reading the data file, we see that it contains 309,215 observations and 13 attributes. Further analysis, including checking for missing values, will be conducted later, as filtering needs to be applied to finalize the dataset.

# %%
USCDI['DataValueUnit'] = USCDI['DataValueUnit'].replace({'cases per 100,000': 'per 100,000'})

# %%
USCDI_filter1 = USCDI[
    (USCDI['LocationDesc'].isin(['Texas', 'Massachusetts'])) &
    (USCDI['Topic'].isin(['Cardiovascular Disease', 'Cancer'])) &
    (USCDI['DataValueUnit'] == "per 100,000")&
    (USCDI['DataValueType'] == "Crude Rate") &
    (USCDI['Stratification1'] == "Overall") &
    (USCDI["Has2019"] == 1)
]

# %%
USCDI_filter2 = USCDI_filter1[['DataValue','Stratification1','Question','LocationDesc', 'Topic', 'DataValueUnit','DataValueType', 'AvgDataValue']]
USCDI_final = pd.merge(USCDI_filter2, KFF2019_new[['Location', 'All_Uninsured']], 
                     left_on='LocationDesc', right_on='Location', how='left')
USCDI_final.drop(columns='Location', inplace=True)
USCDI_final.rename(columns={'AvgDataValue': 'AvgDeathRate'}, inplace=True)
USCDI_final.rename(columns={'DataValueType': 'DeathRateType'}, inplace=True)
USCDI_final.rename(columns={'DataValueUnit': 'DeathRateUnit'}, inplace=True)
USCDI_final.rename(columns={'Topic': 'Disease'}, inplace = True)
USCDI_final.rename(columns={'LocationDesc': 'State'}, inplace = True)

# %%
USCDI_final
# Out:
#     DataValue Stratification1  \
# 0       573.6         Overall
# 1        45.0         Overall
# 2        21.1         Overall
# 3       423.7         Overall
# 4        31.8         Overall
# 5       561.6         Overall
# 6        43.4         Overall
# 7        14.0         Overall
# 8         1.4         Overall
# 9       184.0         Overall
# 10      185.6         Overall
# 11        1.4         Overall
# 12        2.9         Overall
# 13       22.7         Overall
# 14       22.8         Overall
# 15       19.1         Overall
# 16       13.7         Overall
# 17       14.2         Overall
# 18       13.7         Overall
# 19       19.5         Overall
# 20      143.2         Overall
# 21       31.1         Overall
# 22      143.4         Overall
# 23       21.1         Overall
# 24       14.0         Overall
# 25       13.7         Overall
# 26        2.9         Overall
# 27      421.4         Overall
# 28      170.6         Overall
# 29       35.7         Overall
# 30       84.0         Overall
# 31      159.1         Overall
# 32       88.3         Overall
# 33       37.3         Overall
#
#                                              Question          State  \
# 0     Invasive cancer (all sites combined), incidence  Massachusetts
# 1   Lung and bronchial cancer mortality among all ...  Massachusetts
# 2   Breast cancer mortality among all females, und...          Texas
# 3     Invasive cancer (all sites combined), incidence          Texas
# 4   Lung and bronchial cancer mortality among all ...          Texas
# 5     Invasive cancer (all sites combined), incidence  Massachusetts
# 6   Lung and bronchial cancer mortality among all ...  Massachusetts
# 7   Colon and rectum (colorectal) cancer mortality...  Massachusetts
# 8   Cervical cancer mortality among all females, u...  Massachusetts
# 9   Invasive cancer (all sites combined) mortality...  Massachusetts
# 10  Invasive cancer (all sites combined) mortality...  Massachusetts
# 11  Cervical cancer mortality among all females, u...  Massachusetts
# 12  Cervical cancer mortality among all females, u...          Texas
# 13  Breast cancer mortality among all females, und...  Massachusetts
# 14  Breast cancer mortality among all females, und...  Massachusetts
# 15  Prostate cancer mortality among all males, und...  Massachusetts
# 16  Prostate cancer mortality among all males, und...          Texas
# 17  Colon and rectum (colorectal) cancer mortality...  Massachusetts
# 18  Colon and rectum (colorectal) cancer mortality...          Texas
# 19  Prostate cancer mortality among all males, und...  Massachusetts
# 20  Invasive cancer (all sites combined) mortality...          Texas
# 21  Lung and bronchial cancer mortality among all ...          Texas
# 22  Invasive cancer (all sites combined) mortality...          Texas
# 23  Breast cancer mortality among all females, und...          Texas
# 24  Prostate cancer mortality among all males, und...          Texas
# 25  Colon and rectum (colorectal) cancer mortality...          Texas
# 26  Cervical cancer mortality among all females, u...          Texas
# 27    Invasive cancer (all sites combined), incidence          Texas
# 28  Diseases of the heart mortality among all peop...  Massachusetts
# 29  Cerebrovascular disease (stroke) mortality amo...  Massachusetts
# 30  Coronary heart disease mortality among all peo...  Massachusetts
# 31  Diseases of the heart mortality among all peop...          Texas
# 32  Coronary heart disease mortality among all peo...          Texas
# 33  Cerebrovascular disease (stroke) mortality amo...          Texas
#
#                    Disease DeathRateUnit DeathRateType  AvgDeathRate  \
# 0                   Cancer   per 100,000    Crude Rate        114.72
# 1                   Cancer   per 100,000    Crude Rate          9.00
# 2                   Cancer   per 100,000    Crude Rate          4.22
# 3                   Cancer   per 100,000    Crude Rate         84.74
# 4                   Cancer   per 100,000    Crude Rate          6.36
# 5                   Cancer   per 100,000    Crude Rate        112.32
# 6                   Cancer   per 100,000    Crude Rate          8.68
# 7                   Cancer   per 100,000    Crude Rate          2.80
# 8                   Cancer   per 100,000    Crude Rate          0.28
# 9                   Cancer   per 100,000    Crude Rate         36.80
# 10                  Cancer   per 100,000    Crude Rate         37.12
# 11                  Cancer   per 100,000    Crude Rate          0.28
# 12                  Cancer   per 100,000    Crude Rate          0.58
# 13                  Cancer   per 100,000    Crude Rate          4.54
# 14                  Cancer   per 100,000    Crude Rate          4.56
# 15                  Cancer   per 100,000    Crude Rate          3.82
# 16                  Cancer   per 100,000    Crude Rate          2.74
# 17                  Cancer   per 100,000    Crude Rate          2.84
# 18                  Cancer   per 100,000    Crude Rate          2.74
# 19                  Cancer   per 100,000    Crude Rate          3.90
# 20                  Cancer   per 100,000    Crude Rate         28.64
# 21                  Cancer   per 100,000    Crude Rate          6.22
# 22                  Cancer   per 100,000    Crude Rate         28.68
# 23                  Cancer   per 100,000    Crude Rate          4.22
# 24                  Cancer   per 100,000    Crude Rate          2.80
# 25                  Cancer   per 100,000    Crude Rate          2.74
# 26                  Cancer   per 100,000    Crude Rate          0.58
# 27                  Cancer   per 100,000    Crude Rate         84.28
# 28  Cardiovascular Disease   per 100,000    Crude Rate        170.60
# 29  Cardiovascular Disease   per 100,000    Crude Rate         35.70
# 30  Cardiovascular Disease   per 100,000    Crude Rate         84.00
# 31  Cardiovascular Disease   per 100,000    Crude Rate        159.10
# 32  Cardiovascular Disease   per 100,000    Crude Rate         88.30
# 33  Cardiovascular Disease   per 100,000    Crude Rate         37.30
#
#     All_Uninsured
# 0           0.044
# 1           0.044
# 2           0.245
# 3           0.245
# 4           0.245
# 5           0.044
# 6           0.044
# 7           0.044
# 8           0.044
# 9           0.044
# 10          0.044
# 11          0.044
# 12          0.245
# 13          0.044
# 14          0.044
# 15          0.044
# 16          0.245
# 17          0.044
# 18          0.245
# 19          0.044
# 20          0.245
# 21          0.245
# 22          0.245
# 23          0.245
# 24          0.245
# 25          0.245
# 26          0.245
# 27          0.245
# 28          0.044
# 29          0.044
# 30          0.044
# 31          0.245
# 32          0.245
# 33          0.245

# %%
USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Cervical cancer mortality among all females, underlying cause': 
     'Cervical cancer'})

USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Invasive cancer (all sites combined) mortality among all people, underlying cause': 
     'Invasive cancer'})

USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Breast cancer mortality among all females, underlying cause': 
     'Breast cancer'})

USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Colon and rectum (colorectal) cancer mortality among all people, underlying cause': 
     'Colorectal cancer'})

USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Lung and bronchial cancer mortality among all people, underlying cause': 
     'Lung cancer'})

USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Prostate cancer mortality among all males, underlying cause': 
     'Prostate cancer'})

USCDI_final['Question'] = USCDI_final['Question'].replace(
    {'Coronary heart disease mortality among all people, underlying cause': 
     'Coronary heart disease'})

USCDI_final = USCDI_final[USCDI_final['Question'].isin(['Cervical cancer', 'Breast cancer',
                                                        'Colorectal cancer', 'Prostate cancer',
                                                       'Lung cancer', 'Coronary heart disease'])]

USCDI_final.rename(columns={'Question': 'Type'}, inplace=True)
# Out:
# /var/folders/sp/136d3tf94ns_hpp_7z4mgphm0000gp/T/ipykernel_41366/177243834.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USCDI_final.rename(columns={'Question': 'Type'}, inplace=True)

# %% [markdown]
# We selected the necessary attributes to answer this question specifically and renamed some attributes for clarity. Note that we excluded invasive cancer because it is too broad—it includes many different types of "invasive" cancer, making it unsuitable for analyzing the impact of specific cancer types.

# %%
USCDI_final.isnull().sum()
# Out:
# DataValue          0
# Stratification1    0
# Type               0
# State              0
# Disease            0
# DeathRateUnit      0
# DeathRateType      0
# AvgDeathRate       0
# All_Uninsured      0
# dtype: int64

# %% [markdown]
# The attributes needed does not contain missing values, therefore imputation is unnecessary.

# %%
CHD = USCDI_final[
    (USCDI_final['Disease'] == "Cardiovascular Disease")]

CANCER = USCDI_final[USCDI_final['Disease'] == "Cancer"]

# %% [markdown]
# Since we are examining coronary heart disease and cancer, the dataset is divided into two subsets.

# %%
CHD
# Out:
#     DataValue Stratification1                    Type          State  \
# 30       84.0         Overall  Coronary heart disease  Massachusetts
# 32       88.3         Overall  Coronary heart disease          Texas
#
#                    Disease DeathRateUnit DeathRateType  AvgDeathRate  \
# 30  Cardiovascular Disease   per 100,000    Crude Rate          84.0
# 32  Cardiovascular Disease   per 100,000    Crude Rate          88.3
#
#     All_Uninsured
# 30          0.044
# 32          0.245

# %%
CANCER
# Out:
#     DataValue Stratification1               Type          State Disease  \
# 1        45.0         Overall        Lung cancer  Massachusetts  Cancer
# 2        21.1         Overall      Breast cancer          Texas  Cancer
# 4        31.8         Overall        Lung cancer          Texas  Cancer
# 6        43.4         Overall        Lung cancer  Massachusetts  Cancer
# 7        14.0         Overall  Colorectal cancer  Massachusetts  Cancer
# 8         1.4         Overall    Cervical cancer  Massachusetts  Cancer
# 11        1.4         Overall    Cervical cancer  Massachusetts  Cancer
# 12        2.9         Overall    Cervical cancer          Texas  Cancer
# 13       22.7         Overall      Breast cancer  Massachusetts  Cancer
# 14       22.8         Overall      Breast cancer  Massachusetts  Cancer
# 15       19.1         Overall    Prostate cancer  Massachusetts  Cancer
# 16       13.7         Overall    Prostate cancer          Texas  Cancer
# 17       14.2         Overall  Colorectal cancer  Massachusetts  Cancer
# 18       13.7         Overall  Colorectal cancer          Texas  Cancer
# 19       19.5         Overall    Prostate cancer  Massachusetts  Cancer
# 21       31.1         Overall        Lung cancer          Texas  Cancer
# 23       21.1         Overall      Breast cancer          Texas  Cancer
# 24       14.0         Overall    Prostate cancer          Texas  Cancer
# 25       13.7         Overall  Colorectal cancer          Texas  Cancer
# 26        2.9         Overall    Cervical cancer          Texas  Cancer
#
#    DeathRateUnit DeathRateType  AvgDeathRate  All_Uninsured
# 1    per 100,000    Crude Rate          9.00          0.044
# 2    per 100,000    Crude Rate          4.22          0.245
# 4    per 100,000    Crude Rate          6.36          0.245
# 6    per 100,000    Crude Rate          8.68          0.044
# 7    per 100,000    Crude Rate          2.80          0.044
# 8    per 100,000    Crude Rate          0.28          0.044
# 11   per 100,000    Crude Rate          0.28          0.044
# 12   per 100,000    Crude Rate          0.58          0.245
# 13   per 100,000    Crude Rate          4.54          0.044
# 14   per 100,000    Crude Rate          4.56          0.044
# 15   per 100,000    Crude Rate          3.82          0.044
# 16   per 100,000    Crude Rate          2.74          0.245
# 17   per 100,000    Crude Rate          2.84          0.044
# 18   per 100,000    Crude Rate          2.74          0.245
# 19   per 100,000    Crude Rate          3.90          0.044
# 21   per 100,000    Crude Rate          6.22          0.245
# 23   per 100,000    Crude Rate          4.22          0.245
# 24   per 100,000    Crude Rate          2.80          0.245
# 25   per 100,000    Crude Rate          2.74          0.245
# 26   per 100,000    Crude Rate          0.58          0.245

# %% [markdown]
# In terms of outliers, it is not necessary since we do not have a lot of observations. Therefore in order to maintain information, outlier detection and removal is ignored.
#
# A summary table for different types of cancer with descriptive statistics is provided for both states.

# %%
CANCER.groupby(["State","Type"])["AvgDeathRate"].agg(["mean","std","min","max","count"])
# Out:
#                                  mean       std   min   max  count
# State         Type
# Massachusetts Breast cancer      4.55  0.014142  4.54  4.56      2
#               Cervical cancer    0.28  0.000000  0.28  0.28      2
#               Colorectal cancer  2.82  0.028284  2.80  2.84      2
#               Lung cancer        8.84  0.226274  8.68  9.00      2
#               Prostate cancer    3.86  0.056569  3.82  3.90      2
# Texas         Breast cancer      4.22  0.000000  4.22  4.22      2
#               Cervical cancer    0.58  0.000000  0.58  0.58      2
#               Colorectal cancer  2.74  0.000000  2.74  2.74      2
#               Lung cancer        6.29  0.098995  6.22  6.36      2
#               Prostate cancer    2.77  0.042426  2.74  2.80      2

# %% [markdown]
# ## Visualizations

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data= CHD, x='Type', y='AvgDeathRate', hue='State')
plt.xlabel('')
plt.ylabel('Average Death Rate')
plt.title('Coronary Heart Disease Comparison')
plt.legend(title='State')
plt.show()

# %%
eda_summary_cancer = CANCER.groupby(['State', 'Type'])['AvgDeathRate'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=eda_summary_cancer, x='Type', y='AvgDeathRate', hue='State')

plt.xticks(rotation=45, ha='right')
plt.xlabel('Cancer Types')
plt.ylabel('Average Death Rate')
plt.title('Cancer Type Comparison')
plt.legend(title='State')
plt.show()
